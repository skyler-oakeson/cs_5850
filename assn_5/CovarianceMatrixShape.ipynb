# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
import math
pi = math.pi

def PointsInCircum(r,n=200):
    return [(math.cos(2*pi/n*x)*r,math.sin(2*pi/n*x)*r) for x in range(0,n+1)]

# %%
sigmas=[np.array([[1,0],[0,1]]), np.array([[5,0],[0,6]]),np.array([[5,0],[0,1]]),
        np.array([[5,3],[3,5]]),np.array([[10,0],[0,3]]),np.array([[2,0],[0,0]])]

# %%
sigmas
# Out:
# [array([[1, 0],
#         [0, 1]]),
#  array([[5, 0],
#         [0, 6]]),
#  array([[5, 0],
#         [0, 1]]),
#  array([[5, 3],
#         [3, 5]]),
#  array([[10,  0],
#         [ 0,  3]]),
#  array([[2, 0],
#         [0, 0]])]

# %%
X=PointsInCircum(r=1,n=200)

# %%
allresults=[]
for s in sigmas:K
    results=[]
    for x in X:
        results.append(np.matmul(s,x))
    results=np.stack(results)
    #print(results)
    allresults.append(results)

# %%
for s,r in zip(sigmas,allresults):
    plt.figure(figsize=(10,10))
    sns.scatterplot(r[:,0],r[:,1])
    plt.xlim(-12,12)
    plt.ylim(-12,12)
    
    print(s)
    plt.show()
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 for s,r in zip(sigmas,allresults):
#       2     plt.figure(figsize=(10,10))
# ----> 3     sns.scatterplot(r[:,0],r[:,1])
#       4     plt.xlim(-12,12)
#       5     plt.ylim(-12,12)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given
